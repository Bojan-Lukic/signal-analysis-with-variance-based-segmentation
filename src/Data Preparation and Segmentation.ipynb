# %%
#DEMONSTRATION ON TEST SIGNALS

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage.filters import gaussian_filter1d

# create equally spaced points between -5 and 5
x = np.linspace(-5, 5, 19)

# calculate the y value for each element of the x vector
y = -0.5*x**2 + 28.5
y = gaussian_filter1d(y, sigma=14)
y2 = np.zeros(31) + 10
y3 = y2
y3 = np.append(y3, y)
y3 = np.append(y3, y2) 

ysmoothed = gaussian_filter1d(y3, sigma=3.7)
np.savetxt('outfile.txt', ysmoothed, fmt='%d')

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(ysmoothed)    
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)

plt.savefig("Pictures/test_signal.svg", bbox_inches="tight")
plt.show()

# fig, ax = plt.subplots()
# ax.plot(x, y)

# %%
calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(ysmoothed, label = "Test signal")    
plt.axvline(x = 20, color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
plt.axvline(x = 60, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)

plt.savefig("Pictures/test_signal_segmented.svg", bbox_inches="tight")
plt.show()

# %%
calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(ysmoothed, label = "Test signal")    
plt.axvline(x = 20, color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
plt.axvline(x = 40, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.axvline(x = 60, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)

plt.savefig("Pictures/test_signal_segmented_2.svg", bbox_inches="tight")
plt.show()

# %%
# import statistics
# import random
# import numpy as np
# from statistics import variance as var

# arr = []
# tot = []


# rint = random.randint(0, 30)
# rint2 = random.randint(0, 30)
# if rint > rint2:
#     temp = rint
#     rint = rint2
#     rint2 = temp
# arr = arr + [random.randint(rint, rint2) for _ in range(20)]
# for i in range(0, 2):
#     rint = random.randint(50, 60)
#     rint2 = random.randint(50, 60)
#     if rint > rint2:
#         temp = rint
#         rint = rint2
#         rint2 = temp
#     arr = arr + [random.randint(rint, rint2) for _ in range(20)]
#     rint = random.randint(10, 30)
#     rint2 = random.randint(10, 30)
#     if rint > rint2:
#         temp = rint
#         rint = rint2
#         rint2 = temp
#     arr = arr + [random.randint(rint, rint2) for _ in range(20)]
# arr = arr + [random.randint(rint, rint2)]
# tot.append(arr)
# arr = []
    
# np.savetxt('outfile2.txt', tot, fmt='%d')
# print(tot)
# Out:
# [[5, 10, 13, 14, 12, 13, 12, 6, 9, 6, 3, 11, 3, 4, 12, 13, 6, 6, 5, 3, 51, 50, 50, 52, 51, 52, 51, 52, 50, 50, 50, 52, 52, 50, 51, 51, 50, 51, 52, 50, 18, 22, 22, 16, 20, 21, 24, 23, 14, 17, 15, 24, 19, 18, 22, 16, 20, 23, 15, 19, 56, 58, 59, 56, 59, 59, 60, 60, 58, 57, 59, 58, 60, 58, 56, 59, 58, 56, 60, 56, 16, 14, 19, 18, 18, 14, 14, 16, 14, 17, 16, 20, 15, 17, 16, 14, 19, 20, 17, 14, 16]]

# %%
import numpy as np

data = np.loadtxt('outfile2.txt', dtype = int)
A = data

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A) 
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)

plt.savefig("Pictures/test_signal_2.svg", bbox_inches="tight")
plt.show()

# %%
import numpy as np

A = np.loadtxt('outfile2.txt', dtype = int)
calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A, label = "Test signal") 
plt.axvline(x = 10, color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
plt.axvline(x = 30, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.axvline(x = 50, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.axvline(x = 70, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)

plt.savefig("Pictures/test_signal_2_presegmentation.svg", bbox_inches="tight")
plt.show()

# %%
import numpy as np

A = np.loadtxt('outfile2.txt', dtype = int)
calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A, label = "Test signal") 
plt.axvline(x = 20, color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
plt.axvline(x = 40, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.axvline(x = 60, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.axvline(x = 80, color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)

plt.savefig("Pictures/test_signal_2_segmented.svg", bbox_inches="tight")
plt.show()

# %%
#BRUTE FORCE SEGMENTATION

# %%
from statistics import variance as var
import numpy as np

A = np.loadtxt('outfile2.txt', dtype = int)
variance = np.var(A[0:2]) + np.var(A[2:4]) + np.var(A[4:6]) + np.var(A[6:8]) + np.var(A[8:len(A)])
index = [2, 4, 6, 8]

for h in range(2, len(A) - 8):
    for i in range(h + 2, len(A) - 6):
        for j in range(i + 2, len (A) - 4):
            for k in range(j + 2, len (A) - 2):
                tempvar = np.var(A[0:h]) + np.var(A[h:i]) + np.var(A[i:j]) + np.var(A[j:k]) + np.var(A[k:len(A)])
                if tempvar < variance:
                    variance = tempvar
                    index[0] = h
                    index[1] = i
                    index[2] = j
                    index[3] = k
print(index)

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A, label = "Test signal") 
plt.axvline(x = index[0], color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
for xc in range(1, len(index)):
    plt.axvline(x = index[xc], color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.show()

# %%
#SEGMENTATION WITH CUSTOM ALGORITHM

# %%
import statistics
import random
import matplotlib.pyplot as plt
import numpy as np
from statistics import variance as var

A = np.loadtxt('outfile2.txt', dtype=int)

n_segments = 5
preseg = [10, 30, 50, 70]
# for i in range(1, n_segments):
#     preseg.append(int(len(A)*i/n_segments))

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A, label = "Test signal") 
plt.axvline(x = preseg[0], color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
for xc in range(1, len(preseg)):
    plt.axvline(x = preseg[xc], color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.show()

print("Presegmentation:", preseg)
print("")
print("Variance of segment 1:", np.var(A[0:preseg[0]]))
for i in range(0, len(preseg) - 1):
    print("Variance of segment", i + 2, ":", np.var(A[preseg[i]:preseg[i + 1]]))
print("Variance of segment", i + 3, ":", np.var(A[preseg[i + 1]:len(A)]))
var_sum = np.var(A[0:preseg[0]])
for i in range(0, len(preseg) - 1):
    var_sum += np.var(A[preseg[i]:preseg[i + 1]])
var_sum += np.var(A[preseg[i + 1]:len(A)])
print("Sum of variances:", var_sum)
print("")
print("")

var_segments = preseg
thresh = 0

print("Segmentation indices:")
print("")

while thresh < 3:
    for i in range(0, len(var_segments)):
        print(var_segments)
        if i == 0:
            tempvar = np.var(A[0:var_segments[i]])*(var_segments[i])/len(A) + np.var(A[var_segments[i]:var_segments[i + 1]])*(var_segments[i + 1] - var_segments[i])/len(A)
            index = var_segments[i]
            for j in range(2, var_segments[i + 1] - 2):
                tempvar2 = np.var(A[0:j])*(j + 1)/len(A) + np.var(A[j:var_segments[i + 1]])*(var_segments[i + 1] - j)/len(A)
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        elif i == len(var_segments) - 1:
            tempvar = np.var(A[var_segments[i - 1]:var_segments[i]])*(var_segments[i] - var_segments[i - 1])/len(A) + np.var(A[var_segments[i]:len(A)])*(len(A) - var_segments[i])/len(A)
            index = var_segments[i]
            for j in range(var_segments[i - 1] + 2, len(A) - 2):
                tempvar2 = np.var(A[var_segments[i - 1]:j])*(j - var_segments[i - 1])/len(A) + np.var(A[j:len(A)])*(len(A) - j)/len(A)
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        else:
            tempvar = np.var(A[var_segments[i - 1]:var_segments[i]])*(var_segments[i] - var_segments[i - 1])/len(A) + np.var(A[var_segments[i]:var_segments[i + 1]])*(var_segments[i + 1] - var_segments[i])/len(A)
            index = var_segments[i]
            for j in range(var_segments[i - 1] + 2, var_segments[i + 1] - 2):
                tempvar2 = np.var(A[var_segments[i - 1]:j])*(j - var_segments[i - 1])/len(A) + np.var(A[j:var_segments[i + 1]])*(var_segments[i + 1] - j)/len(A)
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        
        var_segments[i] = index
                              
    thresh += 1
    

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A, label = "Test signal") 
plt.axvline(x = var_segments[0], color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
for xc in range(1, len(var_segments)):
    plt.axvline(x = var_segments[xc], color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.show()    
    
print("")
print("")
print("New segmentation:", var_segments)
print("")
print("Variance of segment 1:", np.var(A[0:var_segments[0]]))
for i in range(0, len(var_segments) - 1):
    print("Variance of segment", i + 2, ":", np.var(A[var_segments[i]:var_segments[i + 1]]))
print("Variance of segment", i + 3, ":", np.var(A[var_segments[i + 1]:len(A)]))
var_sum = np.var(A[0:var_segments[0]])
for i in range(0, len(var_segments) - 1):
    var_sum += np.var(A[var_segments[i]:var_segments[i + 1]])
var_sum += np.var(A[var_segments[i + 1]:len(A)])
print("Sum of variances:", var_sum)
# Out:
# Presegmentation: [10, 30, 50, 70]
#
# Variance of segment 1: 10.0
# Variance of segment 2 : 497.8875
# Variance of segment 3 : 248.60999999999996
# Variance of segment 4 : 387.8275
# Variance of segment 5 : 381.89802289282005
# Sum of variances: 1526.22302289282
#
#
# Segmentation indices:
#
# [10, 30, 50, 70]
# [20, 30, 50, 70]
# [20, 40, 50, 70]
# [20, 40, 60, 70]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# [20, 40, 60, 80]
# New segmentation: [20, 40, 60, 80]
#
# Variance of segment 1: 14.809999999999999
# Variance of segment 2 : 0.6899999999999998
# Variance of segment 3 : 9.64
# Variance of segment 4 : 2.0900000000000003
# Variance of segment 5 : 3.9501133786848066
# Sum of variances: 31.18011337868481

# %%
#DATA PREPARATION

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


A = np.loadtxt('all_processes.txt')
A = A.transpose()


def multiplot(results):
    calibri = {'fontname':'Calibri'}
    plt.figure(figsize = (12, 8))
    plt.grid()
    for i in range (0, len(results)):
        plt.plot(results[i])
    plt.xlabel('Reading point r', **calibri, fontsize = 18)
    plt.ylabel('Signal range', **calibri, fontsize = 18)
    plt.yticks(fontsize = 14)
    plt.xticks(fontsize = 14)
    plt.legend(fontsize = 12)


resultall = []
resultallratio = []
minlist = []
ratiolist = []
maxvalue = 0
length = len(A[:, 0])
index = 939 #index 603
x = np.arange(1, length + 1)

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
plt.plot(A[:, 519])
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.savefig("Pictures/sample_process.svg", bbox_inches="tight")
plt.show()

for i in range(0, index):
    result = []
    result = A[:, i]
    
    minlist = np.append(minlist, min(result))
    minimum = min(result)
    result = [x - minimum for x in result]
    resultall.append(result)
    
    ratio = max(result)
    ratiolist.append(round(ratio, 2))
    if ratio > maxvalue:
        maxvalue = ratio


resultallcopy = A.transpose()
multiplot(resultallcopy)
plt.savefig("Pictures/all_processes.svg", bbox_inches="tight")
plt.show()
        
resultallbase = np.array(resultall)
multiplot(resultallbase)
plt.savefig("Pictures/all_processes_base.svg", bbox_inches="tight")
plt.show()

maxvalue2 = max(ratiolist)
ratiolist = [round(x * (1/maxvalue2), 2) for x in ratiolist]
ratiolistunique = np.unique(ratiolist)
ratiolistcount = ratiolistunique
for i in range (0, len(ratiolistunique)):
    ratiolistcount[i] = ratiolist.count(ratiolistunique[i])
y_pos = np.arange(len(ratiolistunique))

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (16, 8))
plt.bar(y_pos, ratiolistcount, align='center', alpha=0.5)
ratiolistunique = np.unique(ratiolist)
for i in range(len(ratiolistcount)):
    plt.text(i, int(ratiolistcount[i]) + 2, int(ratiolistcount[i]), ha = 'center', fontsize = 14)
plt.xlabel('Relative max values', **calibri, fontsize = 18)
plt.ylabel('Frequency', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.show()

threshold = 0.6
for i in range(0, index):
    if max(resultall[i]) > threshold * maxvalue:
        resultall[i] = [x + minlist[i] for x in resultall[i]]
        resultallratio.append(resultall[i])

np.savetxt('filtered_processes.txt', resultallratio)
resultallratio = np.array(resultallratio)
multiplot(resultallratio)
plt.savefig("Pictures/all_processes_filtered.svg", bbox_inches="tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#SEGMENTATION OF FILTERED DATA SET WITH CUSTOM ALGORITHM

# %%
import statistics
import random
import matplotlib.pyplot as plt
import numpy as np
from statistics import variance as var

A = np.loadtxt('filtered_processes.txt')

n_segments = 8
preseg = []
for i in range(1, n_segments):
    preseg.append(int(len(A[1, :])*i/n_segments))

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
for i in range(0, len(A[:, 1])):
    plt.plot(A[i, :])  
plt.axvline(x = preseg[0], color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
for xc in range(1, len(preseg)):
    plt.axvline(x = preseg[xc], color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.savefig("Pictures/all_processes_presegmentation.svg", bbox_inches="tight")
plt.show()

print("Presegmentation:", preseg)
print("")
print("Variance of segment 1:", np.var(A[:, 0:preseg[0]]))
for i in range(0, len(preseg) - 1):
    print("Variance of segment", i + 2, ":", np.var(A[:, preseg[i]:preseg[i + 1]]))
print("Variance of segment", i + 3, ":", np.var(A[:, preseg[i + 1]:len(A[1, :])]))
var_sum = np.var(A[:, 0:preseg[0]])
for i in range(0, len(preseg) - 1):
    var_sum += np.var(A[:, preseg[i]:preseg[i + 1]])
var_sum += np.var(A[:, preseg[i + 1]:len(A[1, :])])
print("Sum of variances:", var_sum)
print("")
print("")

var_segments = preseg
thresh = 0
anim = []

print("Segmentation indices:")
print("")

while thresh < 3:
    for i in range(0, len(var_segments)):
        print(var_segments)
        anim.append(var_segments)
        if i == 0:
            tempvar = np.var(A[:, 0:var_segments[i]])*(var_segments[i])/len(A[1, :]) + \
                np.var(A[:, var_segments[i]:var_segments[i + 1]])*(var_segments[i + 1] - var_segments[i])/len(A[1, :])
            index = var_segments[i]
            for j in range(2, var_segments[i + 1] - 2):
                tempvar2 = np.var(A[:, 0:j])*j/len(A[1, :]) + \
                    np.var(A[:, j:var_segments[i + 1]])*(var_segments[i + 1] - j)/len(A[1, :])
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        elif i == len(var_segments) - 1:
            tempvar = np.var(A[:, var_segments[i - 1]: var_segments[i]])*(var_segments[i] - var_segments[i - 1])/ \
                len(A[1, :]) + np.var(A[:, var_segments[i]:len(A[1, :])])*(len(A[1, :]) - var_segments[i])/len(A[1, :])
            index = var_segments[i]
            for j in range(var_segments[i - 1] + 2, len(A[1, :]) - 2):
                tempvar2 = np.var(A[:, var_segments[i - 1]:j])*(j - var_segments[i - 1])/len(A[1, :]) + \
                    np.var(A[:, j:len(A[1, :])])*(len(A[1, :]) - j)/len(A[1, :])
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        else:
            tempvar = np.var(A[:, var_segments[i - 1]:var_segments[i]])*(var_segments[i] - var_segments[i - 1])/ \
                len(A[1, :]) + np.var(A[:, var_segments[i]:var_segments[i + 1]])* \
                (var_segments[i + 1] - var_segments[i])/len(A[1, :])
            index = var_segments[i]
            for j in range(var_segments[i - 1] + 2, var_segments[i + 1] - 2):
                tempvar2 = np.var(A[:, var_segments[i - 1]:j])*(j - var_segments[i - 1])/len(A[1, :]) + \
                    np.var(A[:, j:var_segments[i + 1]])*(var_segments[i + 1] - j)/len(A[1, :])
                if tempvar2 < tempvar:
                    tempvar = tempvar2
                    index = j
                    thresh = 0
        
        var_segments[i] = index
                              
    thresh += 1
    

calibri = {'fontname':'Calibri'}
plt.figure(figsize = (12, 8))
plt.grid()
for i in range(0, len(A[:, 1])):
    plt.plot(A[i, :])
plt.axvline(x = var_segments[0], color = "red", linestyle = 'dashed', label = "Segmentation line", ymin = 0.02, ymax = 0.98)
for xc in range(1, len(var_segments)):
    plt.axvline(x = var_segments[xc], color = "red", linestyle = 'dashed', ymin = 0.02, ymax = 0.98)
plt.xlabel('Reading point r', **calibri, fontsize = 18)
plt.ylabel('Signal range', **calibri, fontsize = 18)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.legend(fontsize = 12)
plt.savefig("Pictures/all_processes_segmented.svg", bbox_inches="tight")
plt.show()    
    
print("")
print("")
print("New segmentation:", var_segments)
print("")
print("Variance of segment 1:", np.var(A[:, 0:var_segments[0]]))
for i in range(0, len(var_segments) - 1):
    print("Variance of segment", i + 2, ":", np.var(A[:, var_segments[i]:var_segments[i + 1]]))
print("Variance of segment", i + 3, ":", np.var(A[:, var_segments[i + 1]:len(A[1, :])]))
var_sum = np.var(A[:, 0:var_segments[0]])
for i in range(0, len(var_segments) - 1):
    var_sum += np.var(A[:, var_segments[i]:var_segments[i + 1]])
var_sum += np.var(A[:, var_segments[i + 1]:len(A[1, :])])
print("Sum of variances:", var_sum)
# Out:
# Presegmentation: [50, 100, 150, 201, 251, 301, 351]
#
# Variance of segment 1: 0.02407848692012092
# Variance of segment 2 : 0.02470254819580079
# Variance of segment 3 : 0.024044726723584375
# Variance of segment 4 : 0.02340874199416107
# Variance of segment 5 : 0.023338042094895848
# Variance of segment 6 : 0.027149201421994378
# Variance of segment 7 : 0.025306379582728054
# Variance of segment 8 : 0.022573926680160485
# Sum of variances: 0.1946020536134459
#
#
# Segmentation indices:
#
# [50, 100, 150, 201, 251, 301, 351]
# [15, 100, 150, 201, 251, 301, 351]
# [15, 25, 150, 201, 251, 301, 351]
# [15, 25, 159, 201, 251, 301, 351]
# [15, 25, 159, 164, 251, 301, 351]
# [15, 25, 159, 164, 281, 301, 351]
# [15, 25, 159, 164, 281, 313, 351]
# [15, 25, 159, 164, 281, 313, 381]
# [14, 25, 159, 164, 281, 313, 381]
# [14, 25, 159, 164, 281, 313, 381]
# [14, 25, 77, 164, 281, 313, 381]
# [14, 25, 77, 144, 281, 313, 381]
# [14, 25, 77, 144, 281, 313, 381]
# [14, 25, 77, 144, 281, 307, 381]
# ...
